# %% [markdown]
# # <center><font color='RED'>**CAT Reloaded Data Science**</font></center>
#
# <center>
#
# ```
# Beginner's Task 1 — Descriptive Statistics
# ```
#
# </center>

# %% [markdown]
# ---
#
# # Question 1 — Multiple Choice Questions
#
# ---

# %% [markdown]
# ## Q1.1
#
# Library card holders were asked **whether or not they have checked out a book from the library in the past month** (yes or no). Which variable type is suitable for their response?
#
# - ✅ A) Categorical Nominal
# - ⬜ B) Categorical Ordinal
# - ⬜ C) Quantitative Continuous
# - ⬜ D) Quantitative Discrete
#
# **Answer:** A) Categorical Nominal

# %% [markdown]
# ---
#
# ## Q1.2
#
# Library card holders were asked to report **the amount of late fees they have been charged in the past year (input in the form of $XX.XX).** Which variable type is suitable for their response?
#
# - ⬜ A) Categorical Nominal
# - ⬜ B) Categorical Ordinal
# - ✅ C) Quantitative Continuous
# - ⬜ D) Quantitative Discrete
#
# **Answer:** C) Quantitative Continuous

# %% [markdown]
# ---
#
# ## Q1.3
#
# The library recently added a new online checkout/renewal system. Library card holders were asked **how many times they have used the new online system.** What type of variable would their response be considered?
#
# - ⬜ A) Categorical Nominal
# - ⬜ B) Categorical Ordinal
# - ⬜ C) Quantitative Continuous
# - ✅ D) Quantitative Discrete
#
# **Answer:** D) Quantitative Discrete

# %% [markdown]
# ---
#
# ## Q1.4
#
# Library card holders were asked to reflect on their **most recent book they checked out and report the genre that it most closely represented (i.e. Science Fiction, Action, Romance, Mystery, etc.).** What type of variable would their response be considered?
#
# - ✅ A) Categorical Nominal
# - ⬜ B) Categorical Ordinal
# - ⬜ C) Quantitative Continuous
# - ⬜ D) Quantitative Discrete
#
# **Answer:** A) Categorical Nominal

# %% [markdown]
# ---
#
# ## Q1.5
#
# Which of the following is a measure of central tendency?
#
# - ⬜ a) Variance
# - ✅ b) Median
# - ⬜ c) Range
# - ⬜ d) Standard deviation
#
# **Answer:** b) Median

# %% [markdown]
# ---
#
# ## Q1.6
#
# The mean of a dataset is 20 and the median is 14. The distribution is likely:
#
# - ⬜ a) Symmetric
# - ✅ b) Positively skewed
# - ⬜ c) Negatively skewed
# - ⬜ d) Uniform
#
# **Answer:** b) Positively skewed

# %% [markdown]
# ---
#
# ## Q1.7
#
# In a normal distribution, approximately what percentage of values lie within 1 standard deviation of the mean?
#
# - ⬜ a) 34%
# - ⬜ b) 50%
# - ✅ c) 68%
# - ⬜ d) 95%
#
# **Answer:** c) 68%

# %% [markdown]
# ---
#
# ## Q1.8
#
# A sample space for tossing two coins is:
#
# - ⬜ a) {H, T}
# - ✅ b) {HH, HT, TH, TT}
# - ⬜ c) {2, 4, 6, 8}
# - ⬜ d) None of the above
#
# **Answer:** b) {HH, HT, TH, TT}

# %% [markdown]
# ---
#
# ## Q1.9
#
# Which of the following statements is **NOT** True?
#
# - ⬜ A) In a symmetric distribution, the mean and the median are equal.
# - ⬜ B) The first quartile is equal to the twenty-fifth percentile.
# - ⬜ C) In a symmetric distribution, the median is halfway between the first and the third quartiles.
# - ✅ D) The median is always greater than the mean.
# - ⬜ E) The range is the difference between the largest and the smallest observation in the data set.
#
# **Answer:** D) The median is always greater than the mean.

# %% [markdown]
# ---
#
# ## Q1.10
#
# In general, which of the following statements is **FALSE?**
#
# - ⬜ A) The sample mean is more sensitive to extreme values than the median.
# - ⬜ B) The sample range is more sensitive to extreme values than the standard deviation.
# - ⬜ C) The sample standard deviation is a measure of spread around the sample mean.
# - ✅ D) The sample standard deviation is a measure of central tendency around the median.
# - ⬜ E) If a distribution is symmetric, then the mean will be equal to the median.
#
# **Answer:** D) The sample standard deviation is a measure of central tendency around the median.

# %% [markdown]
# ---
#
# ## Q1.11
#
# Suppose a frequency distribution is skewed with a median of 75 and a mode of 80. Which of the following is a possible value for the mean of distribution?
#
# - ⬜ A) 86
# - ⬜ B) 91
# - ✅ C) 64
# - ⬜ D) 75
# - ⬜ E) None of these
#
# **Answer:** C) 64

# %% [markdown]
# ---
#
# ## Q1.12
#
# Which of the following statements about z-scores is correct?
#
# - ✅ A) A z-score measures the deviation of an observation from the mean in standard deviation units.
# - ⬜ B) A z-score measures the absolute deviation of an observation from the mean.
# - ⬜ C) A z-score measures the relative deviation of an observation from the median.
# - ⬜ D) A z-score measures the skewness of a distribution.
#
# **Answer:** A) A z-score measures the deviation of an observation from the mean in standard deviation units.

# %% [markdown]
# ---
#
# ## Q1.13
#
# What is the coefficient of determination (R-squared) in regression analysis?
#
# - ⬜ A) It represents the percentage of data points that fall within one standard deviation of the mean.
# - ⬜ B) It measures the strength and direction of the linear relationship between the independent and dependent variables.
# - ✅ C) It represents the proportion of the variance in the dependent variable that is explained by the independent variable(s).
# - ⬜ D) It measures the spread of the data points around the regression line.
#
# **Answer:** C) It represents the proportion of the variance in the dependent variable that is explained by the independent variable(s).

# %% [markdown]
# ---
#
# ## Q1.14
#
# What does an R-squared value close to 1 indicate?
#
# - ⬜ A) Strong positive correlation
# - ⬜ B) Weak positive correlation
# - ⬜ C) Strong negative correlation
# - ✅ D) The model explains a large proportion of the variance
#
# **Answer:** D) The model explains a large proportion of the variance

# %% [markdown]
# ---
#
# ## Q1.15
#
# Which sampling technique ensures that every member of the population has an equal chance of being selected?
#
# - ⬜ A) Stratified sampling
# - ⬜ B) Cluster sampling
# - ✅ C) Simple random sampling
# - ⬜ D) Convenience sampling
#
# **Answer:** C) Simple random sampling

# %% [markdown]
# ---
#
# ## Q1.16
#
# Which sampling method involves dividing the population into subgroups and then randomly selecting samples from each subgroup?
#
# - ⬜ A) Simple random sampling
# - ✅ B) Stratified sampling
# - ⬜ C) Cluster sampling
# - ⬜ D) Convenience sampling
#
# **Answer:** B) Stratified sampling

# %% [markdown]
# ---
#
# ## Q1.17
#
# Which distribution is commonly used to model continuous data with a symmetric bell-shaped curve?
#
# - ⬜ A) Exponential distribution
# - ⬜ B) Uniform distribution
# - ✅ C) Normal distribution
# - ⬜ D) Poisson distribution
#
# **Answer:** C) Normal distribution

# %% [markdown]
# ---
#
# ## Q1.18
#
# Which of the following statements about residuals in regression is true?
#
# - ✅ A) Residuals are the difference between the predicted values and the actual values
# - ⬜ B) Residuals are always positive
# - ⬜ C) Residuals represent the variability explained by the model
# - ⬜ D) Residuals are used to calculate the R-squared value
#
# **Answer:** A) Residuals are the difference between the predicted values and the actual values

# %% [markdown]
# > **ياراجل قعد خد نفسك القاع مظلم** 😄

# %% [markdown]
# ---
#
# # Question 2 — Open / Calculation Questions
#
# ---

# %% [markdown]
# ## Q2.1
#
# A fair die is rolled. What is the probability of rolling a number greater than 4?
#
# **Answer:**
#
# ```
# Numbers greater than 4 on a fair die: {5, 6}  →  2 outcomes
# Total outcomes: 6
#
# P(X > 4) = 2/6 = 1/3
# ```

# %% [markdown]
# ---
#
# ## Q2.2
#
# You toss a fair coin three times:
#
# - **(a)** What is the probability of three heads?
# - **(b)** What is the probability that you observe exactly one heads?
# - **(c)** Given that you have observed at least one heads, what is the probability that you observe at least two heads?
#
# **Answer:**
#
# ```
# Sample space (3 coin tosses): {HHH, HHT, HTH, HTT, THH, THT, TTH, TTT}  →  8 outcomes
#
# (a) P(HHH) = 1/8
#
# (b) Exactly one H: {HTT, THT, TTH}  →  3 outcomes
#     P(exactly 1 head) = 3/8
#
# (c) At least one H: all outcomes except TTT  →  7 outcomes
#     At least two H: {HHH, HHT, HTH, THH}  →  4 outcomes
#     P(at least 2 H | at least 1 H) = 4/7
# ```

# %% [markdown]
# ---
#
# ## Q2.3
#
# For a sample of 15 students at an elementary-school snack bar, the following sales amounts arranged in ascending order of magnitude are observed:
#
# ```
# 0.10, 0.10, 0.25, 0.25, 0.25, 0.35, 0.40, 0.53, 0.90,
# 1.25, 1.35, 2.45, 2.71, 3.09, 4.10
# ```
#
# Determine the:
# - **(a)** Mean
# - **(b)** Median
# - **(c)** Mode
# - **(d)** How would you describe the distribution from the standpoint of skewness?
#
# **Answer:**
#
# ```
# (a) Mean   = 18.08 / 15 = 1.205
#
# (b) Median = 0.53  (8th value in sorted list)
#
# (c) Mode   = 0.25  (appears 3 times)
#
# (d) The distribution is positively (right) skewed.
#     (Mean > Median > Mode)
# ```

# %% [markdown]
# >![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
# ## Q2.4 — Boxplot Analysis
#
# Given a dataset of 800 measurements, the following statistics are known:
#
# ```
# Range  = max - min = 41
# Q1     = 114
# Q3     = 126
# IQR    = Q3 - Q1 = 12
# ```
#
# > 126 is the Q3 on the boxplot (75th percentile) and 130 is the 80th percentile.
# > The difference between them is 5%.
# >
# > → 0.05 × 800 = **40 measurements**
#
# ### (a) Lower and Upper Bounds
#
# ```
# Lower Bound = Q1 - (1.5 × IQR) = 114 - (1.5 × 12) = 114 - 18 = 96
# Upper Bound = Q3 + (1.5 × IQR) = 126 + (1.5 × 12) = 126 + 18 = 144
# ```
#
# **Answer:**
# - Lower Bound = **96**
# - Upper Bound = **144**

# %% [markdown]
# ---
#
# ## Q2.5 — Outlier Detection
#
# Does the boxplot have any outliers? If yes, tell:
# - Its value.
# - Why do we consider it an outlier?
#
# **Answer:**
#
# ```
# Yes, there is an outlier. Its value is 30.
#
# Reason: It is greater than the upper bound (28.625),
#         so it falls outside the acceptable range and is considered an outlier.
# ```
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > **ياجدع ريح كدة و اشربلك كوباية شاي محدش واخد منها حاجة** ☕

# %% [markdown]
# ---
#
# # Programming Section (PS)
#
# >![image.png](data:image/png;base64,...)

# %% [markdown]
# ## PS.1 — Plus One
#
# > 🔗 [LeetCode: Plus One](https://leetcode.com/problems/plus-one/description/)

# %%
class Solution(object):
    def plusOne(self, digits):
        i = len(digits) - 1

        while i >= 0 and digits[i] == 9:
            digits[i] = 0
            i -= 1

        if i >= 0:
            digits[i] += 1
        else:
            digits.insert(0, 1)

        return digits

# %% [markdown]
# ---
#
# ## PS.2 — Missing Number
#
# > 🔗 [LeetCode: Missing Number](https://leetcode.com/problems/missing-number/description/)

# %%
class Solution(object):
    def missingNumber(self, nums):
        n = len(nums)
        expected = n * (n + 1) // 2
        actual = sum(nums)
        return expected - actual

# %% [markdown]
# ---
#
# ## PS.3 — Bonus: Day of the Year
#
# > 🔗 [LeetCode: Day of the Year](https://leetcode.com/problems/day-of-the-year/description/)

# %%
class Solution(object):
    def dayOfYear(self, date):
        y, m, d = map(int, date.split('-'))

        days_in_month = [31, 28 + self.is_leap(y), 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]

        return sum(days_in_month[:m-1]) + d

    def is_leap(self, year):
        return year % 400 == 0 or (year % 4 == 0 and year % 100 != 0)

# %% [markdown]
# ---
#
# > **مبروك عليك انت حاليا في القاع** 🎉
